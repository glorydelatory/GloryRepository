# %% [markdown]
# <a href="https://colab.research.google.com/github/glorydelatory/GloryRepository/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.image as mping
import matplotlib.pyplot as plt

# %%
imagem = mping.imread('cameraman-1.tif')

# %%
plt.imshow(imagem,cmap = 'gray')
plt.colorbar()

# %%
nbins = 255
h, bin_edges = np.histogram(imagem, nbins,(0,155))
print('h=\n', h)
print ('bins=\n',bin_edges)
# Out:
# h=
#  [   1  280    0 1229  952    0 1216    0  829  824    0  722    0  758
#   817    0  980    0  838 1172    0 1208    0 1353 1123    0  921  648
#     0  502    0  319  265    0  228    0  157  118    0  103    0   95
#    83    0   68    0   76   61    0   81    0   73   65    0   79   66
#     0   58    0   72   81    0   55    0   47   66    0   65    0   72
#    74    0   63    0   76   70    0   73   82    0   78    0   73   82
#     0   86    0   71   64    0   80    0   72   49    0   54    0   49
#    46    0   54    0   51   39    0   39   49    0   45    0   37   37
#     0   53    0   35   47    0   43    0   42   56    0   42    0   61
#    54    0   54   52    0   40    0   45   49    0   48    0   37   49
#     0   52    0   45   60    0   67    0   68   48    0   49    0   49
#    52    0   51   47    0   43    0   38   24    0   34    0   33   35
#     0   31    0   31   49    0   31    0   31   35    0   32   24    0
# ...

# %%
plt.plot(h)

# %%
w=255./nbins
bin_centers = bin_edges[1:]-(w/2)
plt.bar(bin_centers, h, width = w)
plt.title('Histograma da imagem')
# Out:
# Text(0.5, 1.0, 'Histograma da imagem')
